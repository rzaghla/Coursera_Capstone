# %% [markdown]
# <center><h1>Coursera Capstone Notebook</h1></center>
#
# <h4>About this Notebook</h4>
# This notebook created mainly to fulfill data science capstone course provided by IBM on Coursera. This project purpose is to test creator's skill and understanding regarding data analytics with python.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
